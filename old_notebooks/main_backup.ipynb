# %% [markdown]
# # Import modules

# %%
import os
import sys
import requests                      # HTTP client for API calls
import pandas as pd                  # Tabular data handling
from datetime import datetime        # Datetime handling
from typing import Iterable, Optional, Dict, Union
import matplotlib.pyplot as plt
import yfinance as yf
from pprint import pprint as pp

# %% [markdown]
# # Ensure repo root is on PYTHONPATH (CI safety)

# %%
REPO_ROOT = os.path.abspath(os.getcwd())
SRC_PATH = os.path.join(REPO_ROOT, "src")

if SRC_PATH not in sys.path:
    sys.path.insert(0, SRC_PATH)

# %% [markdown]
# # Secrets validation (FAIL FAST)

# %%
try:
    REQUIRED_ENV_VARS = [
        "EMAIL_USER",
        "EMAIL_SENDER",
        "EMAIL_SENDER_PSW",
    ]

    missing = [v for v in REQUIRED_ENV_VARS if not os.getenv(v)]
    if missing:
        raise RuntimeError(
            f"Missing required environment variables: {', '.join(missing)}"
        )

    email_user = os.getenv("EMAIL_USER")
    email_sender_psw = os.getenv("EMAIL_SENDER_PSW")
    email_sender = os.getenv("EMAIL_SENDER")
except Exception as e:
    print(f"Could not find env vars for email users\n{type(e).__name__}: {e}")
    # try:
    #     from dotenv import load_dotenv
    #     load_dotenv()
    #     email_user = os.getenv("EMAIL_USER")
    #     email_sender_psw = os.getenv("EMAIL_SENDER_PSW")
    #     email_sender = os.getenv("EMAIL_SENDER")
    # except KeyError:
    #     raise RuntimeError("Environment variables to send email not found")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.debug_print import debug_print
#       3 try:
#       4     REQUIRED_ENV_VARS = [
#       5         "EMAIL_USER",
#       6         "EMAIL_SENDER",
#       7         "EMAIL_SENDER_PSW",
#       8     ]
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# # Import internal modules

# %%
from src.debug_print import debug_print
from src.fetch_lse_tickers import get_ftse100
from src.exchange_rates import get_share_prices_2 as share_prices
from src.exchange_rates_v2 import get_share_prices_2_with_fundamentals
from src.roi_hit_v2 import get_first_roi_hit
from src.plot_shares_ROI import plot_candles_volatility_volume_roi as ROI
from src.extract_latest_fundamentals import extract_latest_fundamentals
from src.detect_undervalued import detect_undervalued
from src.utils.email_sender import (
    send_email_html_multi_inline_images,
    build_roi_email_with_action_images,
)
from src.utils.email_undervalued_shares import build_undervalued_shares_email_with_images

# %% [markdown]
# # Set up variables

# %%
base_currency = "GBP"
target_currencies = ["USD", "GBP", "EUR", "JPY"]
cryptos = ["BTC", "ETH"]
# purchased_shares = ['FRES','NWG','GLEN','RIO']
purchase_dates = {
    'FRES': pd.Timestamp(2026,1,2),
    'NWG':pd.Timestamp(2026,1,7),
    'GLEN':pd.Timestamp(2026,1,6),
    'RIO':pd.Timestamp(2026,1,8),
}
email_recipients = ["ingcarldan@gmail.com"]

start_date = pd.Timestamp(2024,1,1)
# purchase_date = pd.Timestamp(2026,1,2)
end_date = pd.Timestamp.today().normalize()
ROI_target = 0.135

email_user = os.getenv("EMAIL_USER")
email_sender_psw = os.getenv("EMAIL_SENDER_PSW")
email_sender = os.getenv("EMAIL_SENDER")

# %% [markdown]
# # Ensure output directory exists (CI requirement)

# %%
pics_dir = os.path.join(os.getcwd(), "output")
os.makedirs(pics_dir, exist_ok=True)

# %% [markdown]
# # Get TOP 100 shares from FTSE

# %%
ftse100 = get_ftse100()
ftse100["Yahoo_Ticker"] = ftse100["Ticker"] + ".L"
shares_lse = ftse100["Yahoo_Ticker"].to_list()
# Out:
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\retry_decorator.py
#    Function: wrapper
#    Line: 38
# None get_ftse100 succeeded

# %% [markdown]
# # SHARES PRICES WITH INFO

# %%
df_shares_fund, failed_tickers_list = get_share_prices_2_with_fundamentals(
    tickers=shares_lse,# list with items ending with ".L"
    start=start_date,
    end=end_date,
    base_currency = base_currency,
    vol_window = 20,
    
)

actions_list   = df_shares_fund.columns.get_level_values("ACTION").unique().to_list()
currencies_list = df_shares_fund.columns.get_level_values("CURRENCY").unique()
metrics   = df_shares_fund.columns.get_level_values("METRIC").unique()

# %% [markdown]
# # EXTRACT UNDERVALUED SHARES

# %%
df_fund = extract_latest_fundamentals(
    df=df_shares_fund,
    evaluation_date=end_date,
)

undervalued_shares = detect_undervalued(df_fund)
filt = undervalued_shares[undervalued_shares["UndervaluedScore"] > 0]
undervalued_shares_list = filt.index.to_list()
filt["Ticker"] = filt.index.str.split(".").str[0]

filt["Company"] = (
    filt["Ticker"]
    .map(ftse100.set_index("Ticker")["Company"])
)
currency_convertion = [s.split('_')[1] for s in filt.index.to_list()]

filt['original currency'] = [s.split('→')[0] for s in currency_convertion]
filt['converted currency'] = [s.split('→')[1] for s in currency_convertion]
filt = filt[['Company', 'Ticker', 'UndervaluedScore', 'original currency', 'converted currency', 
                'Price', 'EPS', 'BookValue', 'Dividend', 'P/E', 'P/B']]
ROI(
    df=df_shares_fund,
    actions=filt.index.to_list(), # list with items ending with ".L_GBp→GBP"
    start=df_shares_fund.index.min(),
    end=df_shares_fund.index.max(),
    roi_target=ROI_target,
    plot_purchase=False
)
# Out:
# C:\Users\ingca\AppData\Local\Temp\ipykernel_4796\3987843802.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["Ticker"] = filt.index.str.split(".").str[0]
# C:\Users\ingca\AppData\Local\Temp\ipykernel_4796\3987843802.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["Company"] = (
# C:\Users\ingca\AppData\Local\Temp\ipykernel_4796\3987843802.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt['original currency'] = [s.split('→')[0] for s in currency_convertion]
# C:\Users\ingca\AppData\Local\Temp\ipykernel_4796\3987843802.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt['converted currency'] = [s.split('→')[1] for s in currency_convertion]
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\retry_decorator.py
#    Function: wrapper
#    Line: 38
# None plot_candles_volatility_volume_roi succeeded

# %% [markdown]
# # SEND EMAIL FOR UNDERVALUED SHARES

# %%
try:
    text_body, html_body, inline_images = build_undervalued_shares_email_with_images(
        df_undervalued_shares=filt,
        image_dir='output'
    )

except Exception as e:
    print(f"ERROR in build_undervalued_shares_email_with_images {type(e).__name__}: {e}")
try:
    send_email_html_multi_inline_images(
        smtp_server="smtp.gmail.com",
        smtp_port=587,
        username=email_user,
        password=email_sender_psw,
        sender=email_sender,
        recipients=email_recipients,
        subject=f"FTSE100 - Undevalued shares – {datetime.today():%d-%m-%Y %H:%M}",
        text_body=text_body,
        html_body=html_body,
        inline_images=inline_images,
    )
except Exception as e:
    print(f"Could not run send_email_html_multi_inline_images {type(e).__name__}: {e}")
# Out:
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\email_undervalued_shares.py
#    Function: build_undervalued_shares_email_with_images
#    Line: 64
# None image_dir: c:\Users\ingca\OneDrive\Documents\python\finance\output
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\retry_decorator.py
#    Function: wrapper
#    Line: 38
# None send_email_html_multi_inline_images succeeded

# %% [markdown]
# # ANALYZE SHARES' PORTFOLIO to get ROI Dates

# %%
portfolio = {}
SHARES_FULL_LIST = [s + '.L_GBp→GBP' if not s.endswith('.L_GBp→GBP') else s for s in list(purchase_dates.keys())]

for action in SHARES_FULL_LIST:
    try:
        action_clean = action.split(".L")[0]
        portfolio[action_clean] = get_first_roi_hit(
        df=df_shares_fund,
        action=action,
        purchase_dates=purchase_dates,
        roi_target=ROI_target
    )
    except Exception as e:
        print(f"{type(e).__name__}: {e}")

# %% [markdown]
# #  PLOT SHARE - plot_candles_volatility_volume_roi

# %%
actions = df_shares_fund.columns.get_level_values("ACTION").unique()
mask = actions.str.contains("|".join(list(purchase_dates.keys())), case=False, regex=True)
filtered_actions = actions[mask].to_list()

ROI(
    df=df_shares_fund,
    actions=filtered_actions,
    start=df_shares_fund.index.min(),
    end=df_shares_fund.index.max(),
    purchase_dates=purchase_dates,
    roi_target=ROI_target,
)
# Out:
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\retry_decorator.py
#    Function: wrapper
#    Line: 38
# None plot_candles_volatility_volume_roi succeeded

# %% [markdown]
# # Build email content

# %%
pics_dir = os.path.join(os.getcwd(),"output")

try:
    roi_text_body, roi_html_body, roi_inline_images = build_roi_email_with_action_images(
        roi_data=portfolio, #df_fres,
        image_dir=pics_dir,  # contains AAL.png, VOD.png, ...
    )
except Exception as e:
    print(f"Could not run build_roi_email_with_action_images {type(e).__name__}: {e}")
# Out:
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\email_sender.py
#    Function: build_roi_email_with_action_images
#    Line: 423
# None→ Converted data['PURCHASE DATE'] from str to <class 'pandas._libs.tslibs.timestamps.Timestamp'> 2026-01-02 00:00:00
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\email_sender.py
#    Function: build_roi_email_with_action_images
#    Line: 423
# None→ Converted data['PURCHASE DATE'] from str to <class 'pandas._libs.tslibs.timestamps.Timestamp'> 2026-01-07 00:00:00
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\email_sender.py
#    Function: build_roi_email_with_action_images
#    Line: 423
# None→ Converted data['PURCHASE DATE'] from str to <class 'pandas._libs.tslibs.timestamps.Timestamp'> 2026-01-06 00:00:00
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\email_sender.py
#    Function: build_roi_email_with_action_images
#    Line: 423
# None→ Converted data['PURCHASE DATE'] from str to <class 'pandas._libs.tslibs.timestamps.Timestamp'> 2026-01-08 00:00:00

# %% [markdown]
# # DEBUG CELL

# %%
print("roi_text_body")
pp(roi_text_body)
print("roi_html_body")
pp(roi_html_body)
print("roi_inline_images")
pp(roi_inline_images)
# Out:
# roi_text_body
# ('Data extracted on 09-01-2026 10:38\n'
#  '\n'
#  'Action: FRES\n'
#  '  Target ROI: 13.5%\n'
#  '  Purchase: 33.52 GBP\n'
#  '  Purchase Date: 02-01-2026 00:00\n'
#  '  Exit: 34.40 GBP\n'
#  '\n'
#  'Action: NWG\n'
#  '  Target ROI: 13.5%\n'
#  '  Purchase: 6.32 GBP\n'
#  '  Purchase Date: 07-01-2026 00:00\n'
#  '  Exit: 6.44 GBP\n'
#  '\n'
#  'Action: GLEN\n'
#  '  Target ROI: 13.5%\n'
#  '  Purchase: 4.28 GBP\n'
#  '  Purchase Date: 06-01-2026 00:00\n'
#  '  Exit: 4.13 GBP\n'
#  '\n'
#  'Action: RIO\n'
#  '  Target ROI: 13.5%\n'
#  '  Purchase: 61.94 GBP\n'
#  '  Purchase Date: 08-01-2026 00:00\n'
#  '  Exit: 61.94 GBP\n')
# roi_html_body
# ('\n'
#  '                <html>\n'
#  '                <body style="font-family: Arial, sans-serif;">\n'
#  '                    <h2>ROI targets reached</h2>\n'
#  '                    <p>Data extracted on <b>09-01-2026 10:38</b></p>\n'
#  '\n'
#  '                    <table border="1" cellpadding="6" cellspacing="0">\n'
#  '                        <tr style="background:#f0f0f0;">\n'
#  '                            <th>Action</th>\n'
#  '                            <th>Target ROI</th>\n'
#  '                            <th>Buy Price</th>\n'
#  '                            <th>Buy Date</th>\n'
#  '                            <th>Sell Price</th>\n'
#  '                        </tr>\n'
#  '                        \n'
#  '                <tr>\n'
#  '                    <td><b>FRES</b></td>\n'
#  '                    <td>13.5%</td>\n'
#  '                    <td>33.52 GBP</td>\n'
#  '                    <td>02-01-2026 00:00</td>\n'
#  '                    <td>34.40 GBP</td>\n'
#  '\n'
#  '                </tr>\n'
#  '                \n'
#  '                <tr>\n'
#  '                    <td><b>NWG</b></td>\n'
#  '                    <td>13.5%</td>\n'
#  '                    <td>6.32 GBP</td>\n'
#  '                    <td>07-01-2026 00:00</td>\n'
#  '                    <td>6.44 GBP</td>\n'
#  '\n'
#  '                </tr>\n'
#  '                \n'
#  '                <tr>\n'
#  '                    <td><b>GLEN</b></td>\n'
#  '                    <td>13.5%</td>\n'
#  '                    <td>4.28 GBP</td>\n'
#  '                    <td>06-01-2026 00:00</td>\n'
#  '                    <td>4.13 GBP</td>\n'
#  '\n'
#  '                </tr>\n'
#  '                \n'
#  '                <tr>\n'
#  '                    <td><b>RIO</b></td>\n'
#  '                    <td>13.5%</td>\n'
#  '                    <td>61.94 GBP</td>\n'
#  '                    <td>08-01-2026 00:00</td>\n'
#  '                    <td>61.94 GBP</td>\n'
#  '\n'
#  '                </tr>\n'
#  '                \n'
#  '                    </table>\n'
#  '\n'
#  '                    <hr>\n'
#  '                    \n'
#  '                    <h4>FRES – Price evolution</h4>\n'
#  '                    <img src="cid:FRES_img" style="max-width:900px; '
#  'margin-bottom:20px;">\n'
#  '                    \n'
#  '                    <h4>NWG – Price evolution</h4>\n'
#  '                    <img src="cid:NWG_img" style="max-width:900px; '
#  'margin-bottom:20px;">\n'
#  '                    \n'
#  '                    <h4>GLEN – Price evolution</h4>\n'
#  '                    <img src="cid:GLEN_img" style="max-width:900px; '
#  'margin-bottom:20px;">\n'
#  '                    \n'
#  '                    <h4>RIO – Price evolution</h4>\n'
#  '                    <img src="cid:RIO_img" style="max-width:900px; '
#  'margin-bottom:20px;">\n'
#  '                    \n'
#  '                </body>\n'
#  '                </html>\n'
#  '                ')
# roi_inline_images
# {'FRES_img': WindowsPath('c:/Users/ingca/OneDrive/Documents/python/finance/output/FRES.L_GBp→GBP_ROI.png'),
#  'GLEN_img': WindowsPath('c:/Users/ingca/OneDrive/Documents/python/finance/output/GLEN.L_GBp→GBP_ROI.png'),
#  'NWG_img': WindowsPath('c:/Users/ingca/OneDrive/Documents/python/finance/output/NWG.L_GBp→GBP_ROI.png'),
#  'RIO_img': WindowsPath('c:/Users/ingca/OneDrive/Documents/python/finance/output/RIO.L_GBp→GBP_ROI.png')}

# %% [markdown]
# # Send email (TLS via your utility)

# %%
try:
    send_email_html_multi_inline_images(
        smtp_server="smtp.gmail.com",
        smtp_port=587,
        username=email_user,
        password=email_sender_psw,
        sender=email_sender,
        recipients=email_recipients,
        subject=f"FTSE100 - ROI targets – {datetime.today():%d-%m-%Y %H:%M}",
        text_body=roi_text_body,
        html_body=roi_html_body,
        inline_images=roi_inline_images,
    )
except Exception as e:
    print(f"Could not run send_email_html_multi_inline_images {type(e).__name__}: {e}")
# Out:
# [DEBUG PRINT]
#    File: c:\Users\ingca\OneDrive\Documents\python\finance\src\utils\retry_decorator.py
#    Function: wrapper
#    Line: 38
# None send_email_html_multi_inline_images succeeded
